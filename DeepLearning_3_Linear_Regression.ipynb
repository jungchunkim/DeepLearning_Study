# %% [markdown]
# # Linear Regression

# %% [markdown]
# ![%EC%BA%A1%EC%B2%98-2.PNG](attachment:%EC%BA%A1%EC%B2%98-2.PNG)

# %% [markdown]
# 데이터가 주어졌을 때 그에 맞는 선(hypothesis - H(x) = Wx + b )을 찾는 것이 학습하는 것이다.

# %% [markdown]
# # Cost function ( Loss function )

# %% [markdown]
# ![%EC%BA%A1%EC%B2%98.PNG](attachment:%EC%BA%A1%EC%B2%98.PNG)

# %% [markdown]
# ![%EC%BA%A1%EC%B2%98.PNG](attachment:%EC%BA%A1%EC%B2%98.PNG)

# %% [markdown]
# 목표는 cost(W,b)의 값을 최소화시키는 것! --> 최소화하면 최적화된 H(x)를 구할 수 있다.

# %% [markdown]
# # 텐서플로우를 이용하여 학습

# %%
import tensorflow as tf 
import numpy as np

# X 와 Y 의 데이터
x_train = [1, 2, 3] 
y_train = [1, 2, 3] 

# 버전 2.0 전용

#텐서플로우가 학습하면서 값을 조정해준다.
W = tf.Variable(tf.random.normal([1]), name="weight")
b = tf.Variable(tf.random.normal([1]), name="bias") 

# H(x)=Wx+b 형태
hypothesis=x_train*W+b 
cost = tf.reduce_mean(tf.square(hypothesis - y_train)) 
sgd = tf.keras.optimizers.SGD(learning_rate=0.01)

model = tf.keras.models.Sequential() 
model.add(tf.keras.layers.Dense(1, input_dim = 1))

model.compile(loss='mean_squared_error',optimizer=sgd)

model.fit(x_train,y_train,epochs=1000)

print(model.predict(np.array([5])))
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 311ms/step - loss: 17.6248
# Epoch 2/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 13.9466
# Epoch 3/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 11.0390
# Epoch 4/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 8.7407
# Epoch 5/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9239
# Epoch 6/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4877
# Epoch 7/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.3525
# Epoch 8/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 3.4550
# Epoch 9/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.7456
# Epoch 10/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 2.1847
# Epoch 11/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7414
# Epoch 12/1000
# ...

# %% [markdown]
# # Linear Regressiong의 cost 최소화 알고리즘 원리

# %% [markdown]
# # Gradient descent algorithm
#
# ->기본 개념은 함수의 기울기(경사)를 구하고 경사의 절댓값이 낮은 쪽으로 계속 이동시켜 극값에 이를 때까지 반복시키는 것이다

# %% [markdown]
# ![%EC%BA%A1%EC%B2%98.PNG](attachment:%EC%BA%A1%EC%B2%98.PNG)

# %% [markdown]
# ![%EC%BA%A1%EC%B2%98.PNG](attachment:%EC%BA%A1%EC%B2%98.PNG)

# %% [markdown]
# a에 learning rate 를 지정하여 저 공식을 이용하여 계속 학습시킨다.

# %%
# 위의 식을 python 코드로 나타내보자
learning_rate=0.1
gradient=tf.reduce_mean((W*X-Y)*X)
descent=W-learning_rate*gradient
# update를 실행하면 위의 과정이 실행된다.(학습시키는 것 !)
update= W.assign(descent)

# %%
# 위의 식을 간단하게 이렇게도 표현할 수 있다.
optimizer=tf.train.GradientDescentOptimizer(learning_rate=0.1)
train=optimizer(cost)

# %% [markdown]
# # 값 5.0을 두고 Gradient Descent 을 사용해보자

# %%
import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()

# tf Graph Input
X = [1, 2, 3]
Y = [1, 2, 3]

# Set wrong model weights
W = tf.Variable(5.0)

# Linear model
hypothesis = X * W

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize: Gradient Descent Optimizer
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# Launch the graph in a session.
with tf.Session() as sess:
    # Initializes global variables in the graph.
    sess.run(tf.global_variables_initializer())

    for step in range(101):
        _, W_val = sess.run([train, W])
        print(step, W_val)
# Out:
# WARNING:tensorflow:From c:\users\jeong\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 0 5.0
# 1 1.2666664
# 2 1.0177778
# 3 1.0011852
# 4 1.000079
# 5 1.0000052
# 6 1.0000004
# 7 1.0
# 8 1.0
# 9 1.0
# 10 1.0
# 11 1.0
# 12 1.0
# 13 1.0
# 14 1.0
# 15 1.0
# 16 1.0
# 17 1.0
# 18 1.0
# 19 1.0
# 20 1.0
# 21 1.0
# 22 1.0
# 23 1.0
# 24 1.0
# 25 1.0
# 26 1.0
# 27 1.0
# 28 1.0
# 29 1.0
# 30 1.0
# 31 1.0
# 32 1.0
# 33 1.0
# 34 1.0
# 35 1.0
# 36 1.0
# 37 1.0
# 38 1.0
# 39 1.0
# 40 1.0
# 41 1.0
# 42 1.0
# 43 1.0
# 44 1.0
# 45 1.0
# 46 1.0
# 47 1.0
# 48 1.0
# 49 1.0
# 50 1.0
# 51 1.0
# 52 1.0
# 53 1.0
# 54 1.0
# 55 1.0
# 56 1.0
# 57 1.0
# 58 1.0
# 59 1.0
# 60 1.0
# 61 1.0
# 62 1.0
# 63 1.0
# 64 1.0
# 65 1.0
# 66 1.0
# 67 1.0
# ...
